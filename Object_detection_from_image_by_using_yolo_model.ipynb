# %%
print ("Labony Sur")

# %% [markdown]
# Object Detection By YOLO MODEL

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolo11n.pt') #object detection model

# %%
result=model('/UYYqo.jpg')

# %%
result[0].show()

# %%
result=model('/images.jpg')

# %%
result[0].show()
